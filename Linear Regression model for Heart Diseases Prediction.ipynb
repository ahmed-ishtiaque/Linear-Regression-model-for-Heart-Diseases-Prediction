# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df=pd.read_csv("C:\\Users\\ishtiaque\\Desktop\\6b. ML Projects\\Linear Regression Model for heart diseases dataset\\heart.data.csv")

# %%
df
# Out:
#      Unnamed: 0     biking    smoking  heart.disease
# 0             1  30.801246  10.896608      11.769423
# 1             2  65.129215   2.219563       2.854081
# 2             3   1.959665  17.588331      17.177803
# 3             4  44.800196   2.802559       6.816647
# 4             5  69.428454  15.974505       4.062224
# ..          ...        ...        ...            ...
# 493         494  47.660440  27.562464      11.294392
# 494         495  45.097203  21.385620       9.616762
# 495         496   8.279743   6.423720      13.495168
# 496         497  42.345863  20.741328      10.115865
# 497         498  30.774254  23.610175      11.843556
#
# [498 rows x 4 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 498 entries, 0 to 497
# Data columns (total 4 columns):
# Unnamed: 0       498 non-null int64
# biking           498 non-null float64
# smoking          498 non-null float64
# heart.disease    498 non-null float64
# dtypes: float64(3), int64(1)
# memory usage: 15.7 KB

# %%
df=df.drop('Unnamed: 0',axis=1)

# %%
X=df.drop('heart.disease',axis=1)
y=df['heart.disease']

# %%
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler()
scaler.fit(X)
X=scaler.transform(X)
y=y.to_numpy()

# %%
sns.lmplot(x='biking',y='heart.disease',data=df)

# %%
sns.lmplot(x='smoking',y='heart.disease',data=df)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=0)

# %%
from sklearn import linear_model
clf=linear_model.LinearRegression()

# %%
clf.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
#R^2 value:
print(clf.score(X_train,y_train))
# Out:
# 0.9785746181326693

# %%
y_pred=clf.predict(X_test)
print(y_test,y_pred)
print("Mean Squared Error:",np.mean(y_pred-y_test)**2)
# Out:
# [18.68979793  9.59462272 20.18529061 14.00749014 15.97785224  8.74484531
#  10.37756908  6.75601546 18.48295977 12.81263706  7.62066294 10.54602509
#   4.69552053  7.61880347  5.80949454 17.37053383  4.30318901 15.16277524
#   4.91638345 13.50761916  8.5037463   7.32233219 17.59816609  8.70019788
#  12.3288989  13.33442806 16.02818767 16.60982571 13.79968304 13.64437258
#   7.3303757  11.50759515  4.09076484  8.82823614  2.91165989  5.71773344
#   6.55857962 12.074926    4.94609016  6.83818467  6.80839968 14.41578311
#  16.26510297 16.77863456 12.04664323  2.85408148  2.23921693  6.51267556
#   5.80954305 10.52602928  5.32612719 11.28605704  9.50941843  7.57261423
#   3.74449837  6.7225238  16.79138276  7.47437198  5.69064886  9.23197067
#   6.73577092 14.65635211  7.18494637  1.09448871 11.77859616  4.94799079
#   6.43024815  7.25794619  9.51338391 16.3479313   5.72682702 17.71019095
#   9.79323988  8.54909495 13.37742996  6.71507793 11.9488893   4.36160617
# ...

# %%
print(clf.coef_,clf.intercept_)
# Out:
# [-14.78493794   5.19758452] 14.877625608501816

# %%
#Negative coefficinet for biking indicates downward slope. COefficient related to "smoking" is 5.1975 and 
#bias is 14.877
